# %% [markdown]
# <a href="https://colab.research.google.com/github/charistyretta23/Retta-Repository-ALPRO-/blob/main/Retta_Charisty_F0403251060_POST_TEST_BAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Contoh variabel dengan tipe data berbeda
nama = "Retta"
umur = 19
tinggi = 158
aktif = True

#Menampilkan tipe data variabel
print("Tipe data dari variabel 'nama':",type(nama))
print("Tipe data dari variabel'umur':",type(umur))
print("Tipe data dari variabel'tinggi':",type(tinggi))
print("Tipe data dari variabel'aktif':",type(aktif))
# Out:
# Tipe data dari variabel 'nama': <class 'str'>
# Tipe data dari variabel'umur': <class 'int'>
# Tipe data dari variabel'tinggi': <class 'int'>
# Tipe data dari variabel'aktif': <class 'bool'>

# %%
x = input(str("Masukan angka antara 10-20"))
print("angka yang dimasukan ke dalam sistem adalah", x)
# Out:
# Masukan angka antara 10-2014
# angka yang dimasukan ke dalam sistem adalah 14

# %%
# Program Menentukan Kelulusan Mahasiswa

nilai = float(input("Masukkan nilai mahasiswa: "))
kkm = 75

if nilai >= kkm:
    print("Lulus")
else:
    print("Tidak Lulus")
# Out:
# Masukkan nilai mahasiswa: 90
# Lulus
